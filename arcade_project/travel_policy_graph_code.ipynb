# %%
text_chunks = ["The Travel Policy is applicable to all employees of the company. The Travel Policy is applicable to all employees of the company. All employees of the company are required to undertake business travel within India. The type of travel is defined depending on the duration of travel. Travel duration is classified into Tour, Deputation, and Transfer. A Tour is an official travel which is for a duration of 1 to 15 days. A Deputation is a travel for a duration of 15 days to 1 year. A Transfer is a travel for a duration of more than 1 year. Lodging & Boarding allowances are payable to employees for Tour within India on official work. The limits for Lodging & Boarding allowances are mentioned in Table 4. The company has a classification of Designation with Grades M1 to M6. Grade M1 includes Directors, CEO, COO, and President. Grade M2 includes VP, AVP, GM, DGM, and RM. Grade M3 includes AGM, Sr. Manager, Sr. BM, and RSM. Table 4 categorizes mode of travel into entitlements based on grade. Grade M1-M2 allows taxi AC locally and air economy, train AC I or II, or taxi AC inter-city. Grade M3 allows taxi AC locally and train III AC, bus, or taxi AC inter-city. Auto or taxi non-AC costs 8 Rs. per KM. The Taxi AC costs 10 Rs./KM. The maximum permissible rates mentioned in Table4 are exclusive of taxes. An employee staying at a relative's or friend's place during an official tour will receive 250 Rs. per day as lodging reimbursement. Employees can claim 7.0 Rs per KM for using a Four Wheeler for official work. Employees can claim 2.5 Rs per KM for using a Two Wheeler for official work. The Day Tour Entitlement is calculated on a 24-hour clock basis. The start time of a tour is the start time of departure and the end time is the return time of the tour. For part days, the calculation of duration is as indicated in Table 6. Table 6 specifies the following duration and entitlement: 3 to 12 hours is 50% of daily allowance, and 12 to 24 hours is 100% of daily allowance. All expense claims, except for Boarding and Personal incidental category, must be supported by bills/invoices. A travel for a duration greater than 15 days but less than 1 year at one location or site is treated as deputation. During deputation, the employee is eligible to get entitlements as follows: for 1-7 days, benefits are as per the tour policy mentioned in Point A. Table 7 includes the following entitlements: Lodging Allowance per month and Boarding Allowance per day. The category A travel allowance is 4500 per day. The category B travel allowance is 4000 per day. The daily allowance for category A is 250. The daily allowance for category B is 200. The accommodation allowance for category A is 150. The accommodation allowance for category B is 150. The M4 travel allowance is 4000 per day. The M5 and M6 travel allowance is 4000 per day. The daily allowance for M4, M5, and M6 is 250. If a company provides guest house and food facilities at a site, an employee is not entitled to any travel allowances. An employee does not require to submit bills for deputation entitlements. A relocation or transfer policy applies to an employee shifted to a location for a duration of more than 1 year. The relocation or transfer policy applies if the distance between two places is greater than 100 KM. The initial duration for relocation or transfer is 7 days. Table10: Mode of Travel includes M1/M2: Air (Economy). Table10: Mode of Travel includes M2B: Train (AC II) /Taxi (AC). Table10: Mode of Travel includes M3: Train (III AC) /Bus/Taxi(AC). Table10: Mode of Travel includes M4: Train (III AC)/Bus(AC) /Shared Taxi/Auto. Table10: Mode of Travel includes M5/M6: Train & Bus (Sleeper)/Shared Taxi/ Auto/ Public Conveyance. Taxi or Auto or Public Conveyance costs 10 Rs per kilometer for an AC Taxi. For Grades M3 to M6, the Travel Allowance has a limit of 100. The maximum permissible rates mentioned in Table 4 are exclusive of taxes. All expense claims must be supported by bills or invoices. Relocation Expenses for shifting household goods have a maximum limit of 20,000. For Relocation Expenses, the employee must provide 3 quotations, and HR must verify and approve one. To book a ticket, the employee must send a request email to travel desk at reservation@ujaas.com. In case of non-availability of a particular class of ticket, 1 class down ticket will be booked. The request for travel must be made 1 day prior to the date of travel. The travel desk requests travel approval on email from the supervisor or Head of Department (HOD) before booking a ticket. An employee is not allowed to book a ticket directly unless it is an emergency. For direct ticket booking from a vendor, an employee needs to obtain permission from their HOD, considering the company will make the payment. For direct ticket booking, the employee must show the ticket and the debit or credit card statement. A request mail for booking a ticket must include: Employee Code, Name, Designation, Contact No., Age, Project Name, Purpose, Tour Place, Booking request date, Date of Travel (DOT), Return DOT, Mode info, and Duration. If an employee requests to book a specific flight, additional information must be provided. An employee needs to mention the reason for choosing a Train or Bus in the request mail. The employee needs to send a ticket booking request at least one day before the date of journey. In case of urgent booking, the employee needs to mention the reason for urgent booking. It is not allowed to ask for booking a special Hotel, Flight, Seat, or Web Check-in. The employee needs to submit bills within 15 days of completing a tour. If the employee is not able to submit bills within the given time-limit, the employee needs to attach a note stating a reason for the same. Any tour bills not submitted against tour advances for more than 30 days shall be deducted from the coming month's salary of the employee. The employee needs to provide information on mail in the following format: Employee Code, Name, Designation, Dept., Tour Place. The bill requires the signature of the employee and the employee's Head of Department (HOD). In case of any deviation in the amounts in the bill, the Head of Department (HOD)'s approval with a clarification note is required. If the employee pays bills himself, he needs to submit the bill as well as his credit/debit card statement in case of card payment. It is the responsibility of the employee to obtain authentic bills. When an employee submits a bill for an auto or taxi, the employee needs to mention the name of the places and the distance traveled in the bill for the smooth processing of these kinds of bills.", 'Grade M4 includes Manager, Deputy Manager, Assistant Manager, Sr. Executive, Sr. Engineer, ASM, and BM. Grade M5 includes Executive, Officer, Engineer, and Coordinator. Grade M6 includes Jr. Executive, Jr. Officer, Jr. Engineer, Sr. Technician, Technician. Technician is a Technician. Technician is a Trainee. Operator is a Supervisor. Asst. Engineer is a Supervisor. Grade M4 allows auto or taxi non-AC locally and train III AC, bus AC, shared taxi, or auto inter-city. Grade M5/M6 allows auto for distances under 10 KM and public or shared transport for distances over 10 KM. Taxi AC includes hatchback or sedan cars for M2 and M3 grades. Sedan or SUV cars can be booked for M2 and M3 grades when traveling with a client. The Tour Entitlements are categorized into Grade and Category. Grade A has Lodging Allowance, Boarding Allowance, Personal Incidental Allowance as Actual. Grade B has Lodging Allowance, Boarding Allowance, Personal Incidental Allowance as Actual. M1 has Lodging Allowance, Boarding Allowance, Personal Incidental Allowance as Actual. M2 has Lodging Allowance of 4000, Boarding Allowance of 3000, Personal Incidental Allowance of 1000, and 150. M3 has Lodging Allowance of 3000, Boarding Allowance of 2000, Personal Incidental Allowance of 800, and 125. M4 has Lodging Allowance of 2000, Boarding Allowance of 1500, Personal Incidental Allowance of 600, and 100. M5 has Lodging Allowance of 1500, Boarding Allowance of 1200, Personal Incidental Allowance of 500, and 75. M6 has Lodging Allowance of 1000, Boarding Allowance of 700, Personal Incidental Allowance of 350, and 50. After 7 days of deputation, allowances are provided as per Table 7: Deputation Entitlements, which specifies entitlements by grade. The accommodation allowance for M4, M5, and M6 is 150. Table8: Classification of Designation includes M1: Directors, CEO, COO, President. Table8: Classification of Designation includes M2: VP, AVP. Table8: Classification of Designation includes M2B: DGM, GM, Head, RM. Table8: Classification of Designation includes M3: AGM, Sr. Manager, Sr.BM, RSM. Table8: Classification of Designation includes M4: Manager, Deputy Manager, Assistant Manager, Sr. Executive, Sr. Engineer, ASM, BM. Table8: Classification of Designation includes M5: Executive, Officer, Engineer, Coordinator. Table8: Classification of Designation includes M6: Jr.Executive, Jr.Officer, jr.engineer, Sr.Technician, Technician, Trainee, GET, DET, Operator, Supervisor, Asst. Engineer. The Tour Entitlements table lists Grade, Lodging Allowance, Boarding Allowance, and Travel Allowance for different categories. For Grade A, the Lodging Allowance, Boarding Allowance, and Travel Allowance are actual costs. For Grade M1, the Lodging Allowance, Boarding Allowance, and Travel Allowance are actual costs. For Grade M2, the Lodging Allowance is 4000, Boarding Allowance is 3000, and Travel Allowance is 350. For Grade M2B, the Lodging Allowance is 3000, Boarding Allowance is 2500, and Travel Allowance is 250. For Grade M2, the Travel Allowance has a limit of 150. For Grade M2B, the Travel Allowance has a limit of 125. For Grades M3 to M6, the Lodging Allowance is 2000, Boarding Allowance is 1200, and Travel Allowance is 150. The request mail must also include the approval details: HOD Approved By, or Approved By (in the absence of HOD or above eligibility).', 'GET is a DET. Table 3 categorizes cities into categories. Category A includes NCR, Kolkata, Chennai, Mumbai, Hyderabad, Bangalore, Pune, Ahmedabad, Chandigarh, and capitals of all states and union territories. Category B includes all other cities. Taxi AC costs 10 Rs. per KM. Table9: Classification of Cities includes Category A: NCR, Kolkata, Chennai, Mumbai, Hyderabad, Bangalore, Pune, Ahmedabad, Chandigarh, Capitals of all States/Union Territories. Table9: Classification of Cities includes Category B: All other cities.']

# %%
propositions =['The Travel Policy is applicable to all employees of the company.', 'All employees of the company are required to undertake business travel within India.', 'The type of travel is defined depending on the duration of travel.', 'Travel duration is classified into Tour, Deputation, and Transfer.', 'A Tour is an official travel which is for a duration of 1 to 15 days.', 'A Deputation is a travel for a duration of 15 days to 1 year.', 'A Transfer is a travel for a duration of more than 1 year.', 'Lodging & Boarding allowances are payable to employees for Tour within India on official work.', 'The limits for Lodging & Boarding allowances are mentioned in Table 4.', 'The company has a classification of Designation with Grades M1 to M6.', 'Grade M1 includes Directors, CEO, COO, and President.', 'Grade M2 includes VP, AVP, GM, DGM, and RM.', 'Grade M3 includes AGM, Sr. Manager, Sr. BM, and RSM.', 'Grade M4 includes Manager, Deputy Manager, Assistant Manager, Sr. Executive, Sr. Engineer, ASM, and BM.', 'Grade M5 includes Executive, Officer, Engineer, and Coordinator.', 'Grade M6 includes Jr. Executive, Jr. Officer, Jr. Engineer, Sr. Technician, Technician.', 'Technician is a Technician.', 'Technician is a Trainee.', 'GET is a DET.', 'Operator is a Supervisor.', 'Asst. Engineer is a Supervisor.', 'Table 3 categorizes cities into categories.', 'Category A includes NCR, Kolkata, Chennai, Mumbai, Hyderabad, Bangalore, Pune, Ahmedabad, Chandigarh, and capitals of all states and union territories.', 'Category B includes all other cities.', 'Table 4 categorizes mode of travel into entitlements based on grade.', 'Grade M1-M2 allows taxi AC locally and air economy, train AC I or II, or taxi AC inter-city.', 'Grade M3 allows taxi AC locally and train III AC, bus, or taxi AC inter-city.', 'Grade M4 allows auto or taxi non-AC locally and train III AC, bus AC, shared taxi, or auto inter-city.', 'Grade M5/M6 allows auto for distances under 10 KM and public or shared transport for distances over 10 KM.', 'Taxi AC includes hatchback or sedan cars for M2 and M3 grades.', 'Sedan or SUV cars can be booked for M2 and M3 grades when traveling with a client.', 'Auto or taxi non-AC costs 8 Rs. per KM.', 'Taxi AC costs 10 Rs. per KM.', 'The Taxi AC costs 10 Rs./KM.', 'The Tour Entitlements are categorized into Grade and Category.', 'Grade A has Lodging Allowance, Boarding Allowance, Personal Incidental Allowance as Actual.', 'Grade B has Lodging Allowance, Boarding Allowance, Personal Incidental Allowance as Actual.', 'M1 has Lodging Allowance, Boarding Allowance, Personal Incidental Allowance as Actual.', 'M2 has Lodging Allowance of 4000, Boarding Allowance of 3000, Personal Incidental Allowance of 1000, and 150.', 'M3 has Lodging Allowance of 3000, Boarding Allowance of 2000, Personal Incidental Allowance of 800, and 125.', 'M4 has Lodging Allowance of 2000, Boarding Allowance of 1500, Personal Incidental Allowance of 600, and 100.', 'M5 has Lodging Allowance of 1500, Boarding Allowance of 1200, Personal Incidental Allowance of 500, and 75.', 'M6 has Lodging Allowance of 1000, Boarding Allowance of 700, Personal Incidental Allowance of 350, and 50.', 'The maximum permissible rates mentioned in Table4 are exclusive of taxes.', "An employee staying at a relative's or friend's place during an official tour will receive 250 Rs. per day as lodging reimbursement.", 'Employees can claim 7.0 Rs per KM for using a Four Wheeler for official work.', 'Employees can claim 2.5 Rs per KM for using a Two Wheeler for official work.', 'The Day Tour Entitlement is calculated on a 24-hour clock basis.', 'The start time of a tour is the start time of departure and the end time is the return time of the tour.', 'For part days, the calculation of duration is as indicated in Table 6.', 'Table 6 specifies the following duration and entitlement: 3 to 12 hours is 50% of daily allowance, and 12 to 24 hours is 100% of daily allowance.', 'All expense claims, except for Boarding and Personal incidental category, must be supported by bills/invoices.', 'A travel for a duration greater than 15 days but less than 1 year at one location or site is treated as deputation.', 'During deputation, the employee is eligible to get entitlements as follows: for 1-7 days, benefits are as per the tour policy mentioned in Point A.', 'After 7 days of deputation, allowances are provided as per Table 7: Deputation Entitlements, which specifies entitlements by grade.', 'Table 7 includes the following entitlements: Lodging Allowance per month and Boarding Allowance per day.', 'The category A travel allowance is 4500 per day.', 'The category B travel allowance is 4000 per day.', 'The daily allowance for category A is 250.', 'The daily allowance for category B is 200.', 'The accommodation allowance for category A is 150.', 'The accommodation allowance for category B is 150.', 'The M4 travel allowance is 4000 per day.', 'The M5 and M6 travel allowance is 4000 per day.', 'The daily allowance for M4, M5, and M6 is 250.', 'The accommodation allowance for M4, M5, and M6 is 150.', 'If a company provides guest house and food facilities at a site, an employee is not entitled to any travel allowances.', 'An employee does not require to submit bills for deputation entitlements.', 'A relocation or transfer policy applies to an employee shifted to a location for a duration of more than 1 year.', 'The relocation or transfer policy applies if the distance between two places is greater than 100 KM.', 'The initial duration for relocation or transfer is 7 days.', 'Table8: Classification of Designation includes M1: Directors, CEO, COO, President.', 'Table8: Classification of Designation includes M2: VP, AVP.', 'Table8: Classification of Designation includes M2B: DGM, GM, Head, RM.', 'Table8: Classification of Designation includes M3: AGM, Sr. Manager, Sr.BM, RSM.', 'Table8: Classification of Designation includes M4: Manager, Deputy Manager, Assistant Manager, Sr. Executive, Sr. Engineer, ASM, BM.', 'Table8: Classification of Designation includes M5: Executive, Officer, Engineer, Coordinator.', 'Table8: Classification of Designation includes M6: Jr.Executive, Jr.Officer, jr.engineer, Sr.Technician, Technician, Trainee, GET, DET, Operator, Supervisor, Asst. Engineer.', 'Table9: Classification of Cities includes Category A: NCR, Kolkata, Chennai, Mumbai, Hyderabad, Bangalore, Pune, Ahmedabad, Chandigarh, Capitals of all States/Union Territories.', 'Table9: Classification of Cities includes Category B: All other cities.', 'Table10: Mode of Travel includes M1/M2: Air (Economy).', 'Table10: Mode of Travel includes M2B: Train (AC II) /Taxi (AC).', 'Table10: Mode of Travel includes M3: Train (III AC) /Bus/Taxi(AC).', 'Table10: Mode of Travel includes M4: Train (III AC)/Bus(AC) /Shared Taxi/Auto.', 'Table10: Mode of Travel includes M5/M6: Train & Bus (Sleeper)/Shared Taxi/ Auto/ Public Conveyance.', 'Taxi or Auto or Public Conveyance costs 10 Rs per kilometer for an AC Taxi.', 'The Tour Entitlements table lists Grade, Lodging Allowance, Boarding Allowance, and Travel Allowance for different categories.', 'For Grade A, the Lodging Allowance, Boarding Allowance, and Travel Allowance are actual costs.', 'For Grade M1, the Lodging Allowance, Boarding Allowance, and Travel Allowance are actual costs.', 'For Grade M2, the Lodging Allowance is 4000, Boarding Allowance is 3000, and Travel Allowance is 350.', 'For Grade M2B, the Lodging Allowance is 3000, Boarding Allowance is 2500, and Travel Allowance is 250.', 'For Grade M2, the Travel Allowance has a limit of 150.', 'For Grade M2B, the Travel Allowance has a limit of 125.', 'For Grades M3 to M6, the Lodging Allowance is 2000, Boarding Allowance is 1200, and Travel Allowance is 150.', 'For Grades M3 to M6, the Travel Allowance has a limit of 100.', 'The maximum permissible rates mentioned in Table 4 are exclusive of taxes.', 'All expense claims must be supported by bills or invoices.', 'Relocation Expenses for shifting household goods have a maximum limit of 20,000.', 'For Relocation Expenses, the employee must provide 3 quotations, and HR must verify and approve one.', 'To book a ticket, the employee must send a request email to travel desk at reservation@ujaas.com.', 'In case of non-availability of a particular class of ticket, 1 class down ticket will be booked.', 'The request for travel must be made 1 day prior to the date of travel.', 'The travel desk requests travel approval on email from the supervisor or Head of Department (HOD) before booking a ticket.', 'An employee is not allowed to book a ticket directly unless it is an emergency.', 'For direct ticket booking from a vendor, an employee needs to obtain permission from their HOD, considering the company will make the payment.', 'For direct ticket booking, the employee must show the ticket and the debit or credit card statement.', 'A request mail for booking a ticket must include: Employee Code, Name, Designation, Contact No., Age, Project Name, Purpose, Tour Place, Booking request date, Date of Travel (DOT), Return DOT, Mode info, and Duration.', 'The request mail must also include the approval details: HOD Approved By, or Approved By (in the absence of HOD or above eligibility).', 'If an employee requests to book a specific flight, additional information must be provided.', 'An employee needs to mention the reason for choosing a Train or Bus in the request mail.', 'The employee needs to send a ticket booking request at least one day before the date of journey.', 'In case of urgent booking, the employee needs to mention the reason for urgent booking.', 'It is not allowed to ask for booking a special Hotel, Flight, Seat, or Web Check-in.', 'The employee needs to submit bills within 15 days of completing a tour.', 'If the employee is not able to submit bills within the given time-limit, the employee needs to attach a note stating a reason for the same.', "Any tour bills not submitted against tour advances for more than 30 days shall be deducted from the coming month's salary of the employee.", 'The employee needs to provide information on mail in the following format: Employee Code, Name, Designation, Dept., Tour Place.', "The bill requires the signature of the employee and the employee's Head of Department (HOD).", "In case of any deviation in the amounts in the bill, the Head of Department (HOD)'s approval with a clarification note is required.", 'If the employee pays bills himself, he needs to submit the bill as well as his credit/debit card statement in case of card payment.', 'It is the responsibility of the employee to obtain authentic bills.', 'When an employee submits a bill for an auto or taxi, the employee needs to mention the name of the places and the distance traveled in the bill for the smooth processing of these kinds of bills.']

# %%
semantic_chunks=['The Travel Policy is applicable to all employees of the company.All employees of the company are required to undertake business travel within India .The type of travel is defined depending on the duration of travel.Travel duration is classified into Tour, Deputation, and Transfer .A Tour is an official travel which is for a duration of 1 to 15 days.A Deputation is a travel for a duration of 15 days to 1 year.A Transfer is a travel for a duration of more than 1 year .Lodging & Boarding allowances are payable to employees for Tour within India on official work.The limits for Lodging & Boarding allowances are mentioned in Table 4', '.The company has a classification of Designation with Grades M1 to M6.Grade M1 includes Directors, CEO, COO, and President.Grade M2 includes VP, AVP, GM, DGM, and RM.Grade M3 includes AGM, Sr . Manager, Sr. BM, and RSM.Grade M4 includes Manager, Deputy Manager, Assistant Manager, Sr. Executive, Sr. Engineer, ASM, and BM.Grade M5 includes Executive, Officer, Engineer, and Coordinator .Grade M6 includes Jr. Executive, Jr. Officer, Jr. Engineer, Sr. Technician, Technician.Technician is a Technician.Technician is a Trainee.GET is a DET.Operator is a Supervisor.Asst . Engineer is a Supervisor.Table 3 categorizes cities into categories .Category A includes NCR, Kolkata, Chennai, Mumbai, Hyderabad, Bangalore, Pune, Ahmedabad, Chandigarh, and capitals of all states and union territories.Category B includes all other cities', '.Table 4 categorizes mode of travel into entitlements based on grade.Grade M1-M2 allows taxi AC locally and air economy, train AC I or II, or taxi AC inter-city .Grade M3 allows taxi AC locally and train III AC, bus, or taxi AC inter-city.Grade M4 allows auto or taxi non-AC locally and train III AC, bus AC, shared taxi, or auto inter-city .Grade M5/M6 allows auto for distances under 10 KM and public or shared transport for distances over 10 KM.Taxi AC includes hatchback or sedan cars for M2 and M3 grades .Sedan or SUV cars can be booked for M2 and M3 grades when traveling with a client.Auto or taxi non-AC costs 8 Rs. per KM.Taxi AC costs 10 Rs. per KM.The Taxi AC costs 10 Rs./KM .The Tour Entitlements are categorized into Grade and Category.Grade A has Lodging Allowance, Boarding Allowance, Personal Incidental Allowance as Actual', '.Grade B has Lodging Allowance, Boarding Allowance, Personal Incidental Allowance as Actual.M1 has Lodging Allowance, Boarding Allowance, Personal Incidental Allowance as Actual .M2 has Lodging Allowance of 4000, Boarding Allowance of 3000, Personal Incidental Allowance of 1000, and 150 .M3 has Lodging Allowance of 3000, Boarding Allowance of 2000, Personal Incidental Allowance of 800, and 125 .M4 has Lodging Allowance of 2000, Boarding Allowance of 1500, Personal Incidental Allowance of 600, and 100 .M5 has Lodging Allowance of 1500, Boarding Allowance of 1200, Personal Incidental Allowance of 500, and 75', ".M6 has Lodging Allowance of 1000, Boarding Allowance of 700, Personal Incidental Allowance of 350, and 50.The maximum permissible rates mentioned in Table4 are exclusive of taxes .An employee staying at a relative's or friend's place during an official tour will receive 250 Rs. per day as lodging reimbursement.Employees can claim 7 .0 Rs per KM for using a Four Wheeler for official work.Employees can claim 2.5 Rs per KM for using a Two Wheeler for official work.The Day Tour Entitlement is calculated on a 24-hour clock basis .The start time of a tour is the start time of departure and the end time is the return time of the tour.For part days, the calculation of duration is as indicated in Table 6 .Table 6 specifies the following duration and entitlement: 3 to 12 hours is 50% of daily allowance, and 12 to 24 hours is 100% of daily allowance", '.All expense claims, except for Boarding and Personal incidental category, must be supported by bills/invoices', '.A travel for a duration greater than 15 days but less than 1 year at one location or site is treated as deputation .During deputation, the employee is eligible to get entitlements as follows: for 1-7 days, benefits are as per the tour policy mentioned in Point A', '.After 7 days of deputation, allowances are provided as per Table 7: Deputation Entitlements, which specifies entitlements by grade .Table 7 includes the following entitlements: Lodging Allowance per month and Boarding Allowance per day.The category A travel allowance is 4500 per day.The category B travel allowance is 4000 per day .The daily allowance for category A is 250.The daily allowance for category B is 200.The accommodation allowance for category A is 150.The accommodation allowance for category B is 150 .The M4 travel allowance is 4000 per day.The M5 and M6 travel allowance is 4000 per day.The daily allowance for M4, M5, and M6 is 250.The accommodation allowance for M4, M5, and M6 is 150 .If a company provides guest house and food facilities at a site, an employee is not entitled to any travel allowances.An employee does not require to submit bills for deputation entitlements', '.A relocation or transfer policy applies to an employee shifted to a location for a duration of more than 1 year .The relocation or transfer policy applies if the distance between two places is greater than 100 KM.The initial duration for relocation or transfer is 7 days', '.Table8: Classification of Designation includes M1: Directors, CEO, COO, President.Table8: Classification of Designation includes M2: VP, AVP .Table8: Classification of Designation includes M2B: DGM, GM, Head, RM.Table8: Classification of Designation includes M3: AGM, Sr. Manager, Sr.BM, RSM .Table8: Classification of Designation includes M4: Manager, Deputy Manager, Assistant Manager, Sr. Executive, Sr. Engineer, ASM, BM .Table8: Classification of Designation includes M5: Executive, Officer, Engineer, Coordinator.Table8: Classification of Designation includes M6: Jr.Executive, Jr.Officer, jr.engineer, Sr .Technician, Technician, Trainee, GET, DET, Operator, Supervisor, Asst. Engineer', '.Table9: Classification of Cities includes Category A: NCR, Kolkata, Chennai, Mumbai, Hyderabad, Bangalore, Pune, Ahmedabad, Chandigarh, Capitals of all States/Union Territories .Table9: Classification of Cities includes Category B: All other cities.Table10: Mode of Travel includes M1/M2: Air (Economy).Table10: Mode of Travel includes M2B: Train (AC II) /Taxi (AC) .Table10: Mode of Travel includes M3: Train (III AC) /Bus/Taxi(AC).Table10: Mode of Travel includes M4: Train (III AC)/Bus(AC) /Shared Taxi/Auto .Table10: Mode of Travel includes M5/M6: Train & Bus (Sleeper)/Shared Taxi/ Auto/ Public Conveyance.Taxi or Auto or Public Conveyance costs 10 Rs per kilometer for an AC Taxi .The Tour Entitlements table lists Grade, Lodging Allowance, Boarding Allowance, and Travel Allowance for different categories', '.For Grade A, the Lodging Allowance, Boarding Allowance, and Travel Allowance are actual costs.For Grade M1, the Lodging Allowance, Boarding Allowance, and Travel Allowance are actual costs .For Grade M2, the Lodging Allowance is 4000, Boarding Allowance is 3000, and Travel Allowance is 350 .For Grade M2B, the Lodging Allowance is 3000, Boarding Allowance is 2500, and Travel Allowance is 250.For Grade M2, the Travel Allowance has a limit of 150 .For Grade M2B, the Travel Allowance has a limit of 125.For Grades M3 to M6, the Lodging Allowance is 2000, Boarding Allowance is 1200, and Travel Allowance is 150 .For Grades M3 to M6, the Travel Allowance has a limit of 100.The maximum permissible rates mentioned in Table 4 are exclusive of taxes.All expense claims must be supported by bills or invoices', '.Relocation Expenses for shifting household goods have a maximum limit of 20,000.For Relocation Expenses, the employee must provide 3 quotations, and HR must verify and approve one', '.To book a ticket, the employee must send a request email to travel desk at reservation@ujaas.com.In case of non-availability of a particular class of ticket, 1 class down ticket will be booked .The request for travel must be made 1 day prior to the date of travel.The travel desk requests travel approval on email from the supervisor or Head of Department (HOD) before booking a ticket .An employee is not allowed to book a ticket directly unless it is an emergency .For direct ticket booking from a vendor, an employee needs to obtain permission from their HOD, considering the company will make the payment .For direct ticket booking, the employee must show the ticket and the debit or credit card statement.A request mail for booking a ticket must include: Employee Code, Name, Designation, Contact No', '., Age, Project Name, Purpose, Tour Place, Booking request date, Date of Travel (DOT), Return DOT, Mode info, and Duration', '.The request mail must also include the approval details: HOD Approved By, or Approved By (in the absence of HOD or above eligibility)', ".If an employee requests to book a specific flight, additional information must be provided.An employee needs to mention the reason for choosing a Train or Bus in the request mail .The employee needs to send a ticket booking request at least one day before the date of journey.In case of urgent booking, the employee needs to mention the reason for urgent booking .It is not allowed to ask for booking a special Hotel, Flight, Seat, or Web Check-in.The employee needs to submit bills within 15 days of completing a tour .If the employee is not able to submit bills within the given time-limit, the employee needs to attach a note stating a reason for the same .Any tour bills not submitted against tour advances for more than 30 days shall be deducted from the coming month's salary of the employee", ".The employee needs to provide information on mail in the following format: Employee Code, Name, Designation, Dept., Tour Place .The bill requires the signature of the employee and the employee's Head of Department (HOD) .In case of any deviation in the amounts in the bill, the Head of Department (HOD)'s approval with a clarification note is required .If the employee pays bills himself, he needs to submit the bill as well as his credit/debit card statement in case of card payment.It is the responsibility of the employee to obtain authentic bills .When an employee submits a bill for an auto or taxi, the employee needs to mention the name of the places and the distance traveled in the bill for the smooth processing of these kinds of bills."]

# %%
len(text_chunks)
# Out:
# 3

# %%
type(text_chunks)
# Out:
# list

# %%
pip install grok
# Out:
# Requirement already satisfied: grok in c:\users\vamsi\anaconda3\lib\site-packages (6.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: grokcore.annotation>=1.6 in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.0)
# Requirement already satisfied: grokcore.catalog>=2.1 in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.0)
# Requirement already satisfied: grokcore.chameleon>=1.0 in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.0)
# Requirement already satisfied: grokcore.component>=3.1 in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.0)
# Requirement already satisfied: grokcore.content>=1.2 in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.0)
# Requirement already satisfied: grokcore.formlib>=1.10 in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.0)
# Requirement already satisfied: grokcore.layout>=1.6 in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.0)
# Requirement already satisfied: grokcore.message in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.0)
# Requirement already satisfied: grokcore.security>=1.6 in c:\users\vamsi\anaconda3\lib\site-packages (from grokcore.security[role]>=1.6->grok) (5.0)
# Requirement already satisfied: grokcore.site>=1.7 in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.0)
# Requirement already satisfied: grokcore.traverser>=1.1 in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.0)
# Requirement already satisfied: grokcore.view>=4.1 in c:\users\vamsi\anaconda3\lib\site-packages (from grokcore.view[security-publication]>=4.1->grok) (5.0)
# Requirement already satisfied: grokcore.viewlet>=1.10 in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.0)
# Requirement already satisfied: martian>=1.2 in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (2.1)
# Requirement already satisfied: pytz in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (2023.3.post1)
# Requirement already satisfied: setuptools in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (80.9.0)
# Requirement already satisfied: zc.catalog in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (4.0)
# Requirement already satisfied: ZODB in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (6.0.1)
# Requirement already satisfied: zope.annotation in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.1)
# Requirement already satisfied: zope.app.appsetup in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.0)
# Requirement already satisfied: zope.app.publication in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.0)
# Requirement already satisfied: zope.app.wsgi in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.3)
# Requirement already satisfied: zope.browserpage in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.1)
# Requirement already satisfied: zope.catalog in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.1)
# Requirement already satisfied: zope.component in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (6.0)
# Requirement already satisfied: zope.container in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (6.1)
# Requirement already satisfied: zope.contentprovider in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (6.1)
# Requirement already satisfied: zope.errorview[browser] in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (2.0)
# Requirement already satisfied: zope.event in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.1.1)
# Requirement already satisfied: zope.exceptions in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.2)
# Requirement already satisfied: zope.generations in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.1.0)
# Requirement already satisfied: zope.i18n in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.3)
# Requirement already satisfied: zope.i18nmessageid in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (7.0)
# Requirement already satisfied: zope.interface in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.4.0)
# Requirement already satisfied: zope.intid in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.1)
# Requirement already satisfied: zope.keyreference in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (6.1)
# Requirement already satisfied: zope.lifecycleevent in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.1)
# Requirement already satisfied: zope.location in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.1)
# Requirement already satisfied: zope.login in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (3.1)
# Requirement already satisfied: zope.password in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (6.0)
# Requirement already satisfied: zope.principalregistry in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.1)
# Requirement already satisfied: zope.publisher in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (7.3)
# Requirement already satisfied: zope.schema in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (7.0.1)
# Requirement already satisfied: zope.security in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (7.3)
# Requirement already satisfied: zope.securitypolicy in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.1)
# Requirement already satisfied: zope.site in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.1)
# Requirement already satisfied: zope.traversing in c:\users\vamsi\anaconda3\lib\site-packages (from grok) (5.1)
# Requirement already satisfied: zope.cachedescriptors in c:\users\vamsi\anaconda3\lib\site-packages (from grokcore.annotation>=1.6->grok) (5.1)
# Requirement already satisfied: Chameleon!=4.3 in c:\users\vamsi\anaconda3\lib\site-packages (from grokcore.chameleon>=1.0->grok) (4.6.0)
# Requirement already satisfied: z3c.pt>=2.2.2 in c:\users\vamsi\anaconda3\lib\site-packages (from grokcore.chameleon>=1.0->grok) (5.1)
# Requirement already satisfied: zope.configuration in c:\users\vamsi\anaconda3\lib\site-packages (from grokcore.component>=3.1->grok) (6.0)
# Requirement already satisfied: zope.testing in c:\users\vamsi\anaconda3\lib\site-packages (from grokcore.component>=3.1->grok) (5.1)
# Requirement already satisfied: persistent in c:\users\vamsi\anaconda3\lib\site-packages (from grokcore.content>=1.2->grok) (6.1.1)
# Requirement already satisfied: zope.formlib>=4.3.0 in c:\users\vamsi\anaconda3\lib\site-packages (from grokcore.formlib>=1.10->grok) (6.1)
# Requirement already satisfied: zope.authentication in c:\users\vamsi\anaconda3\lib\site-packages (from grokcore.layout>=1.6->grok) (5.1)
# Requirement already satisfied: zope.dottedname in c:\users\vamsi\anaconda3\lib\site-packages (from grokcore.security>=1.6->grokcore.security[role]>=1.6->grok) (6.0)
# Requirement already satisfied: zope.browserresource>=3.9 in c:\users\vamsi\anaconda3\lib\site-packages (from grokcore.view>=4.1->grokcore.view[security-publication]>=4.1->grok) (5.2)
# Requirement already satisfied: zope.pagetemplate in c:\users\vamsi\anaconda3\lib\site-packages (from grokcore.view>=4.1->grokcore.view[security-publication]>=4.1->grok) (5.1)
# Requirement already satisfied: zope.ptresource>=3.9 in c:\users\vamsi\anaconda3\lib\site-packages (from grokcore.view>=4.1->grokcore.view[security-publication]>=4.1->grok) (5.1)
# Requirement already satisfied: zope.viewlet in c:\users\vamsi\anaconda3\lib\site-packages (from grokcore.viewlet>=1.10->grok) (5.1)
# Requirement already satisfied: zope.hookable>=4.2.0 in c:\users\vamsi\anaconda3\lib\site-packages (from zope.component->grok) (7.0)
# Requirement already satisfied: zope.deprecation in c:\users\vamsi\anaconda3\lib\site-packages (from zope.site->grok) (5.1)
# Requirement already satisfied: z3c.flashmessage in c:\users\vamsi\anaconda3\lib\site-packages (from grokcore.message->grok) (4.0)
# Requirement already satisfied: BTrees>=4.4.1 in c:\users\vamsi\anaconda3\lib\site-packages (from zc.catalog->grok) (6.1)
# Requirement already satisfied: zope.index>=4.3.0 in c:\users\vamsi\anaconda3\lib\site-packages (from zc.catalog->grok) (7.0)
# Requirement already satisfied: zope.deferredimport in c:\users\vamsi\anaconda3\lib\site-packages (from zope.container->grok) (5.0)
# Requirement already satisfied: zope.filerepresentation in c:\users\vamsi\anaconda3\lib\site-packages (from zope.container->grok) (6.1)
# Requirement already satisfied: zope.proxy>=4.1.5 in c:\users\vamsi\anaconda3\lib\site-packages (from zope.container->grok) (6.1)
# Requirement already satisfied: zope.size in c:\users\vamsi\anaconda3\lib\site-packages (from zope.container->grok) (5.1)
# Requirement already satisfied: multipart>=1.1.0 in c:\users\vamsi\anaconda3\lib\site-packages (from zope.publisher->grok) (1.3.0)
# Requirement already satisfied: zope.browser in c:\users\vamsi\anaconda3\lib\site-packages (from zope.publisher->grok) (3.1)
# Requirement already satisfied: zope.contenttype>=4.0.0 in c:\users\vamsi\anaconda3\lib\site-packages (from zope.publisher->grok) (5.2)
# Requirement already satisfied: python-gettext in c:\users\vamsi\anaconda3\lib\site-packages (from zope.i18n->grok) (5.0)
# Requirement already satisfied: transaction in c:\users\vamsi\anaconda3\lib\site-packages (from zope.traversing->grok) (5.0)
# Requirement already satisfied: ZConfig in c:\users\vamsi\anaconda3\lib\site-packages (from ZODB->grok) (4.2)
# Requirement already satisfied: zc.lockfile in c:\users\vamsi\anaconda3\lib\site-packages (from ZODB->grok) (3.0.post1)
# Requirement already satisfied: zodbpickle>=1.0.1 in c:\users\vamsi\anaconda3\lib\site-packages (from ZODB->grok) (4.2)
# Requirement already satisfied: zdaemon in c:\users\vamsi\anaconda3\lib\site-packages (from zope.app.appsetup->grok) (5.2.1)
# Requirement already satisfied: zope.error in c:\users\vamsi\anaconda3\lib\site-packages (from zope.app.appsetup->grok) (5.1)
# Requirement already satisfied: zope.processlifetime in c:\users\vamsi\anaconda3\lib\site-packages (from zope.app.appsetup->grok) (3.1)
# Requirement already satisfied: zope.session>=4.0.0a1 in c:\users\vamsi\anaconda3\lib\site-packages (from zope.app.appsetup->grok) (5.2)
# Requirement already satisfied: zope.tal>=4.2.0 in c:\users\vamsi\anaconda3\lib\site-packages (from zope.browserpage->grok) (5.1)
# Requirement already satisfied: zope.tales in c:\users\vamsi\anaconda3\lib\site-packages (from zope.contentprovider->grok) (6.1)
# Requirement already satisfied: cffi in c:\users\vamsi\anaconda3\lib\site-packages (from persistent->grokcore.content>=1.2->grok) (1.16.0)
# Requirement already satisfied: zope.datetime in c:\users\vamsi\anaconda3\lib\site-packages (from zope.formlib>=4.3.0->grokcore.formlib>=1.10->grok) (5.1)
# Requirement already satisfied: zope.minmax in c:\users\vamsi\anaconda3\lib\site-packages (from zope.session>=4.0.0a1->zope.app.appsetup->grok) (2.3)
# Requirement already satisfied: pycparser in c:\users\vamsi\anaconda3\lib\site-packages (from cffi->persistent->grokcore.content>=1.2->grok) (2.21)

# %%
# groq_llm.py
from langchain.llms.base import LLM
from groq import Groq
from pydantic import BaseModel, Field
from typing import Optional, List

class GroqLLM(LLM, BaseModel):

    api_key: str = Field("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")

    model: str = "meta-llama/llama-4-scout-17b-16e-instruct"
    temperature: float = 1.0
    max_tokens: int = 1024
    top_p: float = 1.0

    def _call(self, prompt: str, stop: Optional[List[str]] = None, **kwargs) -> str:
        client = Groq(api_key=self.api_key)

        try:
            response = client.chat.completions.create(
                model=self.model,
                messages=[{"role": "user", "content": prompt}],
                temperature=self.temperature,
                max_tokens=self.max_tokens,
                top_p=self.top_p,
                stream=False
            )
            return response.choices[0].message.content
        except Exception as e:
            return f"Error occurred: {str(e)}"

    @property
    def _llm_type(self) -> str:
        return "groq"

    @property
    def _identifying_params(self):
        return {
            "model": self.model,
            "temperature": self.temperature,
            "max_tokens": self.max_tokens,
            "top_p": self.top_p
        }

# %%
llm = GroqLLM()

# %%
answer = llm.invoke('Hi')
answer
# Out:
# 'Hi! How are you today? Is there something I can help you with or would you like to chat?'

# %%
from typing import Dict
import json 
import re

# %%
def extract_graph_schema_from_text(text: str) -> Dict:
    """
    Extract entities and relationships with their types and properties.
    """
    prompt = f"""
Given the following text:
\"\"\"{text}\"\"\"

Extract:
1. A list of entities, with each entity having:
   - name
   - type
   - properties (as key-value pairs)

2. A list of relationships between entities, with:
   - source entity name
   - target entity name
   - type of relation
   - properties (if any)

Only Return the result as a valid JSON object, and should not contain any other text or ''', 
should not contain any headings or language or format-types( like json )and details , 
i need a clean json object that should start with a curly brackets and end with curly braces 

example output format:
{{
  "entities": [
    {{
      "name": "Uday",
      "type": "Person",
      "properties": {{
        "age": 28,
        "city": "Hyderabad"
      }}
    }},
    ...
  ],
  "relations": [
    {{
      "source": "Uday",
      "target": "TCS",
      "type": "WORKS_IN",
      "properties": {{
        "since": 2020
      }}
    }},
    ...
  ]
}}
"""
    output = llm._call(prompt)
    try:
        # Extract JSON code block between triple backticks (``` or ```json)
        code_block_match = re.search(r"```(?:json)?(.*?)```", output, re.DOTALL)
        if code_block_match:
            cleaned = code_block_match.group(1).strip()
        else:
            # If no code block found, try to parse raw string directly
            cleaned = output.strip()

        # Load the cleaned string as JSON
        return json.loads(cleaned)
    
    except Exception as e:
        print("❌ Failed to parse JSON from LLM:", e)
        print("Raw Output:", output)
        return {"entities": [], "relations": []}

# %%
extract_graph_schema_from_text(semantic_chunks[2])
# Out:
# {'entities': [{'name': 'Grade',
#    'type': 'Classification',
#    'properties': {'M1-M2': 'Taxi AC locally, air economy, train AC I or II, or taxi AC inter-city',
#     'M3': 'Taxi AC locally, train III AC, bus, or taxi AC inter-city',
#     'M4': 'Auto or taxi non-AC locally, train III AC, bus AC, shared taxi, or auto inter-city',
#     'M5/M6': 'Auto for distances under 10 KM and public or shared transport for distances over 10 KM'}},
#   {'name': 'Taxi AC',
#    'type': 'Vehicle',
#    'properties': {'cost': 10, 'unit': 'Rs./KM'}},
#   {'name': 'Taxi non-AC',
#    'type': 'Vehicle',
#    'properties': {'cost': 8, 'unit': 'Rs./KM'}},
#   {'name': 'Tour Entitlements',
#    'type': 'Concept',
#    'properties': {'Grade A': 'Lodging Allowance, Boarding Allowance, Personal Incidental Allowance as Actual'}},
#   {'name': 'Lodging Allowance', 'type': 'Allowance', 'properties': {}},
#   {'name': 'Boarding Allowance', 'type': 'Allowance', 'properties': {}},
#   {'name': 'Personal Incidental Allowance',
#    'type': 'Allowance',
#    'properties': {}}],
#  'relations': [{'source': 'Grade',
#    'target': 'Taxi AC',
#    'type': 'ALLOWED_IN',
#    'properties': {'grades': ['M1-M2', 'M3']}},
#   {'source': 'Grade',
#    'target': 'Taxi non-AC',
#    'type': 'ALLOWED_IN',
#    'properties': {'grades': ['M4']}},
#   {'source': 'Tour Entitlements',
#    'target': 'Grade A',
#    'type': 'HAS_GRADE',
#    'properties': {}},
#   {'source': 'Grade A',
#    'target': 'Lodging Allowance',
#    'type': 'HAS_ALLOWANCE',
#    'properties': {}},
#   {'source': 'Grade A',
#    'target': 'Boarding Allowance',
#    'type': 'HAS_ALLOWANCE',
#    'properties': {}},
#   {'source': 'Grade A',
#    'target': 'Personal Incidental Allowance',
#    'type': 'HAS_ALLOWANCE',
#    'properties': {}}]}

# %%
extract_graph_schema_from_text(propositions[3])
# Out:
# {'entities': [{'name': 'Travel Duration', 'type': 'Concept', 'properties': {}},
#   {'name': 'Tour', 'type': 'Classification', 'properties': {}},
#   {'name': 'Deputation', 'type': 'Classification', 'properties': {}},
#   {'name': 'Transfer', 'type': 'Classification', 'properties': {}}],
#  'relations': [{'source': 'Travel Duration',
#    'target': 'Tour',
#    'type': 'IS_CLASSIFIED_AS',
#    'properties': {}},
#   {'source': 'Travel Duration',
#    'target': 'Deputation',
#    'type': 'IS_CLASSIFIED_AS',
#    'properties': {}},
#   {'source': 'Travel Duration',
#    'target': 'Transfer',
#    'type': 'IS_CLASSIFIED_AS',
#    'properties': {}}]}

# %%
import json

class GraphTypeCache:
    def __init__(self, llm, similarity_threshold=0.8):
        self.vertex_types = set()
        self.edge_types = set()
        self.llm = llm
        self.similarity_threshold = similarity_threshold
        logging.info("GraphTypeCache initialized with similarity_threshold=%.2f", similarity_threshold)

    def load_from_db(self):
        global run_cypher
        logging.info("Loading vertex and edge types from database...")

        try:
            label_query = "MATCH (n) RETURN DISTINCT labels(n) AS labels"
            label_result = run_cypher(label_query)
            self.vertex_types = {
                label for row in label_result['result'] for label in row['labels']
            }
            logging.info("Loaded vertex types: %s", self.vertex_types)

            rel_query = "MATCH ()-[r]->() RETURN DISTINCT type(r) AS relationship_type"
            rel_result = run_cypher(rel_query)
            self.edge_types = {
                row['relationship_type'] for row in rel_result['result']
            }
            logging.info("Loaded edge types: %s", self.edge_types)

        except Exception as e:
            logging.error("Failed to load types from database: %s", e)

    def _llm_match(self, new_type, existing_types, type_kind):
        if not existing_types:
            return None

        prompt = f"""
You are a smart semantic matcher for a graph database.

Check if the NEW {type_kind} TYPE is equivalent to any of the EXISTING {type_kind.upper()} TYPES.

NEW TYPE: '{new_type}'
EXISTING TYPES: {list(existing_types)}

Your task:
- If the new type is just a variation, abbreviation, misspelling, or synonym of an existing type, return the CLOSEST MATCH.
- If it is a new type entirely, return 'NONE'.

Only return:
- An EXACT existing type from the list above, or
- 'NONE'

Answer ONLY with the type name or 'NONE'.
"""
        logging.info("[LLM PROMPT]:\n%s", prompt)
        response = self.llm.invoke(prompt).strip().strip('"\'')
        logging.info("[LLM RESPONSE]: %s", response)

    # Normalize and check if it's a known type
        if response in existing_types:
            return response
        else:
            logging.warning("LLM response not in existing types: '%s'", response)
            return None



    def find_closest_vertex_type(self, label: str) -> str:
        logging.info("Finding closest vertex type for '%s'", label)
        match = self._llm_match(label, self.vertex_types, "vertex")
        if match:
            logging.info("Vertex type '%s' matched to existing '%s'", label, match)
        else:
            logging.info("Vertex type '%s' is treated as new", label)
        return match if match else label

    def find_closest_edge_type(self, rel: str) -> str:
        logging.info("Finding closest edge type for '%s'", rel)
        match = self._llm_match(rel, self.edge_types, "edge")
        if match:
            logging.info("Edge type '%s' matched to existing '%s'", rel, match)
        else:
            logging.info("Edge type '%s' is treated as new", rel)
        return match if match else rel

    def add_vertex_type(self, label: str):
        logging.info("Adding new vertex type to cache: '%s'", label)
        self.vertex_types.add(label)

    def add_edge_type(self, rel: str):
        logging.info("Adding new edge type to cache: '%s'", rel)
        self.edge_types.add(rel)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 cache.vertex_types.size()
#
# NameError: name 'cache' is not defined

# %%
def normalize(text: str) -> str:
    return text.lower().strip()

def map_graph_schema_with_cache(graph):
    updated_graph = {'entities': [], 'relations': []}

    # Process entities (vertex types)
    for entity in graph.get('entities', []):
        original_type = normalize(entity['type'])
        mapped_type = cache.find_closest_vertex_type(original_type)

        if mapped_type == original_type:
            cache.add_vertex_type(mapped_type)

        entity['type'] = mapped_type
        updated_graph['entities'].append(entity)

    # Process relations (edge types)
    for rel in graph.get('relations', []):
        original_type = normalize(rel['type'])
        mapped_type = cache.find_closest_edge_type(original_type)

        if mapped_type == original_type:
            cache.add_edge_type(mapped_type)

        rel['type'] = mapped_type
        updated_graph['relations'].append(rel)

    return updated_graph

# %%
def get_cypher_queries_from_llm(graph: dict, llm) -> list:
    mapped_graph = map_graph_schema_with_cache(graph)
    prompt = f"""
You are a Cypher query generator.

Your job is to produce a list of valid **Cypher queries** based on the provided graph schema. Each query must be a **self-contained single line** that does **not depend on previous lines**.

---

### ⚠️ Restrictions:

**Type Naming:**
- Only use **letters, numbers, and underscores**.
- Do NOT use slashes, dashes, parentheses, or special characters in labels.
- Convert labels like `"Credit/Debit Card"` → `"Credit_Debit_Card"`.

**Variable Use:**
- Use variables (`a`, `b`, etc.) **only inside the same query**.
- Do NOT reuse variables across multiple queries.
- Every Cypher query must be valid even if run independently.

**Relationship Creation:**
- If you're creating a relationship, include both node definitions and the relationship in **one single line**:
MERGE (a:Label1 ) MERGE (b:Label2 ) MERGE (a)-[:REL_TYPE]->(b)

markdown
Copy
Edit

**Output Format:**
- Only return a **Python list** of Cypher query strings.
["MERGE ...", "MERGE ..."]

yaml
Copy
Edit
- Do NOT return Markdown, code blocks, or explanations , return only a list of cypher query strings.
- All string values must use **single quotes**.
- Do NOT include unnecessary empty maps unless required.

---

### 🧠 Graph Schema:
Here is the schema for your graph:
```json
{json.dumps(mapped_graph)}
Generate queries that respect this schema and the rules above.
"""

    
    response = llm.invoke(prompt).strip()

    try:
        result = eval(response)
        if isinstance(result, list):
            return result
    except Exception as e:
        print("❌ Failed to parse response:", e)
        print("Raw LLM Output:", response)

    return []

# %% [markdown]
# Creating graph into the database

# %%
import requests
from requests.auth import HTTPBasicAuth 
BASE_URL = "http://localhost:2480"
AUTH = HTTPBasicAuth("root", "playwithdata")

# %%
db_name = "test_policy_graph"

# %%
def create_database(name):
    url = f"{BASE_URL}/api/v1/server"
    payload = { "command": f"create database {name}" }
    response = requests.post(url, json=payload, auth=AUTH)
    print(f"[CREATE DB] Status: {response.status_code}\nResponse: {response.text}\n")

create_database(db_name)
# Out:
# [CREATE DB] Status: 200
# Response: {"result":"ok"}

# %%
"""def delete_database(name):
    url = f"{BASE_URL}/api/v1/server"
    payload = { "command": f"drop database {name}" }
    response = requests.post(url, json=payload, auth=AUTH)
    print(f"[DELETE DB] Status: {response.status_code}\nResponse: {response.text}\n")
delete_database("travel_policy_test") """
# Out:
# [DELETE DB] Status: 200
# Response: {"result":"ok"}

# %%
def run_cypher(query:str):
    url = f"{BASE_URL}/api/v1/command/{db_name}"
    payload = {"language":"Cypher","command":query}
    response = requests.post(url,json = payload,auth = AUTH)
    print(f"[RUN CYPHER] Status:{response.status_code}\n Response :{response.text}\n")
    return response.json()

# %%
import logging

# %%
for sentence in semantic_chunks[:1]:
    graph_data = extract_graph_schema_from_text(sentence)
    print(graph_data)
    query_list = get_cypher_queries_from_llm(graph_data,llm)
    print(query_list)
# Out:
# ❌ Failed to parse JSON from LLM: Expecting value: line 1 column 1 (char 0)
# Raw Output: Error occurred: Error code: 400 - {'error': {'message': 'Organization has been restricted. Please reach out to support if you believe this was in error.', 'type': 'invalid_request_error', 'code': 'organization_restricted'}}
# {'entities': [], 'relations': []}
# ❌ Failed to parse response: invalid syntax (<string>, line 1)
# Raw LLM Output: Error occurred: Error code: 400 - {'error': {'message': 'Organization has been restricted. Please reach out to support if you believe this was in error.', 'type': 'invalid_request_error', 'code': 'organization_restricted'}}
# []

# %%
cache = GraphTypeCache(llm)
cache.load_from_db()
# Out:
# [RUN CYPHER] Status:200
#  Response :{"result":[{"labels":["Travel_Policy"]},{"labels":["Air"]},{"labels":["Employee"]},{"labels":["Train"]},{"labels":["Tour"]},{"labels":["M5_M6"]},{"labels":["Taxi_Auto_Public_Conveyance"]},{"labels":["Deputation"]},{"labels":["Transfer"]},{"labels":["Grade_A"]},{"labels":["Grade_M1"]},{"labels":["Lodging_Boarding_allowances"]},{"labels":["Grade_M2"]},{"labels":["Table4"]},{"labels":["Grade_M2B"]},{"labels":["Entity"]},{"labels":["Grades_M3_M6"]},{"labels":["Grade"]},{"labels":["Relocation_Expenses"]},{"labels":["Taxi_AC"]},{"labels":["Quotation"]},{"labels":["Taxi_non_AC"]},{"labels":["HR"]},{"labels":["Tour_Entitlements"]},{"labels":["Lodging_Allowance"]},{"labels":["Travel_Desk"]},{"labels":["Boarding_Allowance"]},{"labels":["Supervisor"]},{"labels":["Personal_Incidental_Allowance"]},{"labels":["Head_of_Department"]},{"labels":["Grade_B"]},{"labels":["Vendor"]},{"labels":["M1"]},{"labels":["Ticket"]},{"labels":["M2"]},{"labels":["M3"]},{"labels":["Tour_Place"]},{"labels":["Date_of_Travel_DOT"]},{"labels":["M4"]},{"labels":["M5"]},{"labels":["Return_DOT"]},{"labels":["M6"]},{"labels":["Booking_request_date"]},{"labels":["Four_Wheeler"]},{"labels":["Request_Mail"]},{"labels":["Two_Wheeler"]},{"labels":["Approval_Details"]},{"labels":["HOD"]},{"labels":["Expense_Claim"]},{"labels":["Boarding"]},{"labels":["Flight"]},{"labels":["Personal_Incidental"]},{"labels":["Bus"]},{"labels":["Credit_Debit_Card"]},{"labels":["Hotel"]},{"labels":["Tour_Policy"]},{"labels":["Ticket_Booking_Request"]},{"labels":["Company"]},{"labels":["Bill"]},{"labels":["Deputation_Entitlements"]},{"labels":["Tour_Advance"]},{"labels":["Category_A"]},{"labels":["Salary"]},{"labels":["Category_B"]},{"labels":["Auto_Taxi"]},{"labels":["Relocation_Policy"]},{"labels":["Location"]},{"labels":["Table8"]},{"labels":["M2B"]},{"labels":["City"]},{"labels":["M1_M2"]}]}
#
# [RUN CYPHER] Status:200
#  Response :{"result":[{"relationship_type":"located_at"},{"relationship_type":"description"},{"relationship_type":"applicable_to"},{"relationship_type":"instance_of"},{"relationship_type":"before"},{"relationship_type":"undergoes"},{"relationship_type":"used_by"},{"relationship_type":"involves"},{"relationship_type":"similar_to"},{"relationship_type":"entitled_to"},{"relationship_type":"defined_in"},{"relationship_type":"RELATIONSHIP"},{"relationship_type":"related_to"},{"relationship_type":"makes"},{"relationship_type":"incurs"},{"relationship_type":"works_for"},{"relationship_type":"submits"},{"relationship_type":"provides"},{"relationship_type":"verifies_and_approves"},{"relationship_type":"requires"},{"relationship_type":"affected_by"},{"relationship_type":"paid_by"},{"relationship_type":"includes"},{"relationship_type":"sends_request_to"},{"relationship_type":"travels_by"},{"relationship_type":"part_of"},{"relationship_type":"books_ticket_from"},{"relationship_type":"books"}]}

# %%
print(len(cache.vertex_types))
print(len(cache.edge_types))
# Out:
# 71
# 28

# %% [markdown]
# Checking the queries

# %%
for sentence in semantic_chunks[17:18]:
    graph_data = extract_graph_schema_from_text(sentence)
    print(graph_data)
    query_list = get_cypher_queries_from_llm(graph_data,llm)
    print(query_list)
    for query in query_list:
        run_cypher(query)
# Out:
# ```
# {
#   "entities": [
#     {
#       "name": "Employee",
#       "type": "Person",
#       "properties": {
#         "code": "",
#         "name": "",
#         "designation": "",
#         "dept": ""
#       }
#     },
#     {
#       "name": "Head of Department",
#       "type": "Person",
#       "properties": {}
#     },
#     {
#       "name": "Bill",
#       "type": "Document",
#       "properties": {
#         "amount": "",
#         "date": ""
#       }
#     },
#     {
#       "name": "Credit/Debit Card",
#       "type": "Payment Method",
#       "properties": {
#         "cardNumber": "",
#         "expirationDate": ""
#       }
#     },
#     {
#       "name": "Auto/Taxi",
#       "type": "Vehicle",
#       "properties": {
#         "name": "",
#         "distance": ""
#       }
#     },
#     {
#       "name": "Department",
#       "type": "Organization",
#       "properties": {}
#     }
#   ],
#   "relations": [
#     {
#       "source": "Employee",
#       "target": "Head of Department",
#       "type": "REPORTS_TO",
#       "properties": {}
#     },
#     {
#       "source": "Employee",
#       "target": "Bill",
#       "type": "SUBMITS",
#       "properties": {}
#     },
#     {
#       "source": "Head of Department",
#       "target": "Bill",
#       "type": "APPROVES",
#       "properties": {}
#     },
#     {
#       "source": "Bill",
#       "target": "Credit/Debit Card",
#       "type": "PAID_WITH",
#       "properties": {}
#     },
#     {
#       "source": "Employee",
#       "target": "Department",
#       "type": "BELONGS_TO",
#       "properties": {}
#     },
#     {
#       "source": "Bill",
#       "target": "Auto/Taxi",
#       "type": "FOR",
#       "properties": {
#         "distance": "",
#         "places": ""
#       }
#     }
#   ]
# }
# ```
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[49], line 4
#       2 graph_data = extract_graph_schema_from_text(sentence)
#       3 print(graph_data)
# ----> 4 graph_data = json.loads(graph_data)
#       5 query_list = get_cypher_queries_from_llm(graph_data,llm)
#       6 print(query_list)
#
# File ~\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~\anaconda3\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~\anaconda3\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# graph_creation function

# %% [raw]
# """def map_graph_schema_with_cache(graph):
#     updated_graph = {'entities': [], 'relations': []}
#     name_map = {}
#
#     for entity in graph.get('entities', []):
#         original = entity['name']
#         mapped = cache.find_closest_vertex_type(original)
#         if mapped == original:
#             cache.add_vertex_type(mapped)
#         entity['name'] = mapped
#         name_map[original] = mapped
#         updated_graph['entities'].append(entity)
#
#     for rel in graph.get('relations', []):
#         rel['source'] = name_map.get(rel['source'], rel['source'])
#         rel['target'] = name_map.get(rel['target'], rel['target'])
#
#         original_rel = rel['type']
#         mapped_rel = cache.find_closest_edge_type(original_rel)
#         if mapped_rel == original_rel:
#             cache.add_edge_type(mapped_rel)
#         rel['type'] = mapped_rel
#
#         updated_graph['relations'].append(rel)
#
#     return updated_graph
#     """

# %% [raw]
# """def map_graph_schema_with_cache(graph):
#     updated_graph = {'entities': [], 'relations': []}
#     logging.info("Starting schema mapping with cache...")
#
#     for entity in graph.get('entities', []):
#         original_name = entity['name']
#         original_type = entity['type']
#         logging.info("Processing entity: %s (%s)", original_name, original_type)
#
#         mapped_type = cache.find_closest_vertex_type(original_type)
#
#         if mapped_type == original_type:
#             logging.info("New vertex type detected: '%s'. Adding to cache.", mapped_type)
#             cache.add_vertex_type(mapped_type)
#         else:
#             logging.info("Mapped vertex type: '%s' → '%s'", original_type, mapped_type)
#
#         entity['type'] = mapped_type
#         updated_graph['entities'].append(entity)
#
#     for rel in graph.get('relations', []):
#         original_rel = rel['type']
#         logging.info("Processing relation: %s → %s (%s)",
#                      rel['source'], rel['target'], original_rel)
#
#         mapped_rel = cache.find_closest_edge_type(original_rel)
#
#         if mapped_rel == original_rel:
#             logging.info("New edge type detected: '%s'. Adding to cache.", mapped_rel)
#             cache.add_edge_type(mapped_rel)
#         else:
#             logging.info("Mapped edge type: '%s' → '%s'", original_rel, mapped_rel)
#
#         rel['type'] = mapped_rel
#         updated_graph['relations'].append(rel)
#
#     logging.info("Completed schema mapping. Updated graph: %s", updated_graph)
#     return updated_graph
# """

# %%
for sentence in semantic_chunks[1:]:
    print(sentence)
    graph_data = extract_graph_schema_from_text(sentence)
    print(graph_data)
    query_list = get_cypher_queries_from_llm(graph_data,llm)
    print(query_list)
# Out:
# .The company has a classification of Designation with Grades M1 to M6.Grade M1 includes Directors, CEO, COO, and President.Grade M2 includes VP, AVP, GM, DGM, and RM.Grade M3 includes AGM, Sr . Manager, Sr. BM, and RSM.Grade M4 includes Manager, Deputy Manager, Assistant Manager, Sr. Executive, Sr. Engineer, ASM, and BM.Grade M5 includes Executive, Officer, Engineer, and Coordinator .Grade M6 includes Jr. Executive, Jr. Officer, Jr. Engineer, Sr. Technician, Technician.Technician is a Technician.Technician is a Trainee.GET is a DET.Operator is a Supervisor.Asst . Engineer is a Supervisor.Table 3 categorizes cities into categories .Category A includes NCR, Kolkata, Chennai, Mumbai, Hyderabad, Bangalore, Pune, Ahmedabad, Chandigarh, and capitals of all states and union territories.Category B includes all other cities
# ❌ Failed to parse JSON from LLM: Expecting value: line 1 column 1 (char 0)
# Raw Output: ```
# {
#   "entities": [
#     {
#       "name": "Director",
#       "type": "Designation",
#       "properties": {
#         "grade": "M1"
#       }
#     },
#     {
#       "name": "CEO",
#       "type": "Designation",
#       "properties": {
#         "grade": "M1"
#       }
#     },
#     {
#       "name": "COO",
#       "type": "Designation",
#       "properties": {
#         "grade": "M1"
#       }
#     },
#     {
#       "name": "President",
#       "type": "Designation",
#       "properties": {
#         "grade": "M1"
#       }
#     },
#     {
#       "name": "VP",
#       "type": "Designation",
#       "properties": {
#         "grade": "M2"
#       }
#     },
#     {
#       "name": "AVP",
#       "type": "Designation",
#       "properties": {
#         "grade": "M2"
#       }
#     },
#     {
#       "name": "GM",
#       "type": "Designation",
#       "properties": {
#         "grade": "M2"
#       }
#     },
#     {
#       "name": "DGM",
#       "type": "Designation",
#       "properties": {
#         "grade": "M2"
#       }
#     },
#     {
#       "name": "RM",
#       "type": "Designation",
#       "properties": {
#         "grade": "M2"
#       }
#     },
#     {
#       "name": "AGM",
#       "type": "Designation",
#       "properties": {
#         "grade": "M3"
#       }
#     },
#     {
#       "name": "Sr. Manager",
#       "type": "Designation",
#       "properties": {
#         "grade": "M3"
#       }
#     },
#     {
#       "name": "Sr. BM",
#       "type": "Designation",
#       "properties": {
#         "grade": "M3"
#       }
#     },
#     {
#       "name": "RSM",
#       "type": "Designation",
#       "properties": {
#         "grade": "M3"
#       }
#     },
#     {
#       "name": "Manager",
#       "type": "Designation",
#       "properties": {
#         "grade": "M4"
#       }
#     },
#     {
#       "name": "Deputy Manager",
#       "type": "Designation",
#       "properties": {
#         "grade": "M4"
#       }
#     },
#     {
#       "name": "Assistant Manager",
#       "type": "Designation",
#       "properties": {
#         "grade": "M4"
#       }
#     },
#     {
#       "name": "Sr. Executive",
#       "type": "Designation",
#       "properties": {
#         "grade": "M4"
#       }
#     },
#     {
#       "name": "Sr. Engineer",
#       "type": "Designation",
#       "properties": {
#         "grade": "M4"
#       }
#     },
#     {
#       "name": "ASM",
#       "type": "Designation",
#       "properties": {
#         "grade": "M4"
#       }
#     },
#     {
#       "name": "BM",
#       "type": "Designation",
#       "properties": {
#         "grade": "M4"
#       }
#     },
#     {
#       "name": "Executive",
#       "type": "Designation",
#       "properties": {
#         "grade": "M5"
#       }
#     },
#     {
#       "name": "Officer",
#       "type": "Designation",
#       "properties": {
#         "grade": "M5"
#       }
#     },
#     {
#       "name": "Engineer",
#       "type": "Designation",
#       "properties": {
#         "grade": "M5"
#       }
#     },
#     {
#       "name": "Coordinator",
#       "type": "Designation",
#       "properties": {
#         "grade": "M5"
#       }
#     },
#     {
#       "name": "Jr. Executive",
#       "type": "Designation",
#       "properties": {
#         "grade": "M6"
#       }
#     },
#     {
#       "name": "Jr. Officer",
#       "type": "Designation",
#       "properties": {
#         "grade": "M6"
#       }
#     },
#     {
#       "name": "Jr. Engineer",
#       "type": "Designation",
#       "properties": {
#         "grade": "M6"
#       }
#     },
#     {
#       "name": "Sr. Technician",
#       "type": "Designation",
#       "properties": {
#         "grade": "M6"
#       }
#     },
#     {
#       "name": "Technician",
#       "type": "Designation",
#       "properties": {
#         "grade": "M6"
#       }
#     },
#     {
#       "name
# {'entities': [], 'relations': []}
# ❌ Failed to parse response: invalid syntax (<string>, line 1)
# Raw LLM Output: Since the provided graph schema is empty, I will generate a few basic Cypher queries that can be used to create nodes and relationships in a graph database.
#
# Here are some example queries:
#
# ["CREATE (a:Person {name: 'John'} )",
# "CREATE (a:Person {name: 'Jane'} )",
# "MERGE (a:Person {name: 'John'} ) MERGE (b:Person {name: 'Jane'} ) MERGE (a)-[:FRIEND_OF]->(b)"]
#
# However, to better follow the given schema which seems to indicate an empty structure, I will instead focus on very basic node creation:
#
# ["CREATE (a:Node {name: 'Example_Node'} )"]
# []
# .Table 4 categorizes mode of travel into entitlements based on grade.Grade M1-M2 allows taxi AC locally and air economy, train AC I or II, or taxi AC inter-city .Grade M3 allows taxi AC locally and train III AC, bus, or taxi AC inter-city.Grade M4 allows auto or taxi non-AC locally and train III AC, bus AC, shared taxi, or auto inter-city .Grade M5/M6 allows auto for distances under 10 KM and public or shared transport for distances over 10 KM.Taxi AC includes hatchback or sedan cars for M2 and M3 grades .Sedan or SUV cars can be booked for M2 and M3 grades when traveling with a client.Auto or taxi non-AC costs 8 Rs. per KM.Taxi AC costs 10 Rs. per KM.The Taxi AC costs 10 Rs./KM .The Tour Entitlements are categorized into Grade and Category.Grade A has Lodging Allowance, Boarding Allowance, Personal Incidental Allowance as Actual
# {'entities': [{'name': 'Grade', 'type': 'Category', 'properties': {'M1-M2': 'Taxi AC locally, air economy, train AC I or II, or taxi AC inter-city', 'M3': 'Taxi AC locally, train III AC, bus, or taxi AC inter-city', 'M4': 'Auto or taxi non-AC locally, train III AC, bus AC, shared taxi, or auto inter-city', 'M5/M6': 'Auto for distances under 10 KM, public or shared transport for distances over 10 KM'}}, {'name': 'Taxi AC', 'type': 'Mode of Travel', 'properties': {'cost': '10 Rs. per KM', 'includes': 'hatchback or sedan cars for M2 and M3 grades'}}, {'name': 'Taxi non-AC', 'type': 'Mode of Travel', 'properties': {'cost': '8 Rs. per KM'}}, {'name': 'Auto', 'type': 'Mode of Travel', 'properties': {'cost': '8 Rs. per KM'}}, {'name': 'Train', 'type': 'Mode of Travel', 'properties': {'classes': 'I, II, III, AC, non-AC'}}, {'name': 'Bus', 'type': 'Mode of Travel', 'properties': {'classes': 'AC, non-AC'}}, {'name': 'Tour Entitlements', 'type': 'Category', 'properties': {'Grade A': 'Lodging Allowance, Boarding Allowance, Personal Incidental Allowance as Actual'}}], 'relations': [{'source': 'Grade', 'target': 'Taxi AC', 'type': 'ALLOWED_FOR', 'properties': {'grades': 'M1-M2, M3'}}, {'source': 'Grade', 'target': 'Taxi non-AC', 'type': 'ALLOWED_FOR', 'properties': {'grades': 'M4'}}, {'source': 'Grade', 'target': 'Auto', 'type': 'ALLOWED_FOR', 'properties': {'grades': 'M4, M5/M6'}}, {'source': 'Taxi AC', 'target': 'Train', 'type': 'COMPARED_TO', 'properties': {'cost': '10 Rs. per KM'}}, {'source': 'Tour Entitlements', 'target': 'Grade A', 'type': 'CATEGORIZES', 'properties': {'entitlements': 'Lodging Allowance, Boarding Allowance, Personal Incidental Allowance as Actual'}}]}
# WARNING:root:LLM response not in existing types: 'Category_B
# or
# Category_A
#
# More specifically, I will return:
# Category_A'
# WARNING:root:LLM response not in existing types: 'Travel type'
# WARNING:root:LLM response not in existing types: 'similar_to
#
# or alternatively:
# related_to
#
# But more specifically and accurately:
# categorizes seems closest to:
# instance_of
#
# However upon re-examination
# categorizes is very similar to:
# defines
#
# defines is close but a better answer would be:
# classifies is not there however
# instance_of and
# part_of
#
# And a  good match
# categorizes
# is
# classified under  no
# but
# is_a  no
#
# 'categorizes' seems a close synonym to
# 'type of '  which matches:
# instance_of
#
#  returns
# instance_of'
# ["MERGE (a:Grade {name: 'M1-M2'}) MERGE (b:Taxi_AC {cost: '10 Rs. per KM'}) MERGE (a)-[:entitled_to {grades: 'M1-M2'}]->(b)", "MERGE (a:Grade {name: 'M3'}) MERGE (b:Taxi_AC {cost: '10 Rs. per KM'}) MERGE (a)-[:entitled_to {grades: 'M3'}]->(b)", "MERGE (a:Grade {name: 'M4'}) MERGE (b:Taxi_non_AC {cost: '8 Rs. per KM'}) MERGE (a)-[:entitled_to {grades: 'M4'}]->(b)", "MERGE (a:Grade {name: 'M4'}) MERGE (b:Auto {cost: '8 Rs. per KM'}) MERGE (a)-[:entitled_to {grades: 'M4'}]->(b)", "MERGE (a:Grade {name: 'M5/M6'}) MERGE (b:Auto {cost: '8 Rs. per KM'}) MERGE (a)-[:entitled_to {grades: 'M5/M6'}]->(b)", "MERGE (a:Taxi_AC {cost: '10 Rs. per KM'}) MERGE (b:Train {classes: 'I, II, III, AC, non-AC'}) MERGE (a)-[:similar_to {cost: '10 Rs. per KM'}]->(b)", "MERGE (a:Tour_Entitlements {name: 'Grade A'}) MERGE (b:Grade {name: 'Grade A'}) MERGE (a)-[:categorizes {entitlements: 'Lodging Allowance, Boarding Allowance, Personal Incidental Allowance as Actual'}]->(b)"]
# .Grade B has Lodging Allowance, Boarding Allowance, Personal Incidental Allowance as Actual.M1 has Lodging Allowance, Boarding Allowance, Personal Incidental Allowance as Actual .M2 has Lodging Allowance of 4000, Boarding Allowance of 3000, Personal Incidental Allowance of 1000, and 150 .M3 has Lodging Allowance of 3000, Boarding Allowance of 2000, Personal Incidental Allowance of 800, and 125 .M4 has Lodging Allowance of 2000, Boarding Allowance of 1500, Personal Incidental Allowance of 600, and 100 .M5 has Lodging Allowance of 1500, Boarding Allowance of 1200, Personal Incidental Allowance of 500, and 75
# {'entities': [{'name': 'Grade B', 'type': 'Grade', 'properties': {'Lodging Allowance': 'Actual', 'Boarding Allowance': 'Actual', 'Personal Incidental Allowance': 'Actual'}}, {'name': 'M1', 'type': 'Grade', 'properties': {'Lodging Allowance': 'Actual', 'Boarding Allowance': 'Actual', 'Personal Incidental Allowance': 'Actual'}}, {'name': 'M2', 'type': 'Grade', 'properties': {'Lodging Allowance': 4000, 'Boarding Allowance': 3000, 'Personal Incidental Allowance': 1000, 'other': 150}}, {'name': 'M3', 'type': 'Grade', 'properties': {'Lodging Allowance': 3000, 'Boarding Allowance': 2000, 'Personal Incidental Allowance': 800, 'other': 125}}, {'name': 'M4', 'type': 'Grade', 'properties': {'Lodging Allowance': 2000, 'Boarding Allowance': 1500, 'Personal Incidental Allowance': 600, 'other': 100}}, {'name': 'M5', 'type': 'Grade', 'properties': {'Lodging Allowance': 1500, 'Boarding Allowance': 1200, 'Personal Incidental Allowance': 500, 'other': 75}}], 'relations': []}
# WARNING:root:LLM response not in existing types: 'Grade_A
# is close, but
# Grade
#
# NONE
# but
#
# Grade
#
# is actually
#
# Grade
#
# so answer is
#
# Grade'
# ["MERGE (a:Grade_B {Lodging_Allowance: 'Actual', Boarding_Allowance: 'Actual', Personal_Incidental_Allowance: 'Actual'})", "MERGE (a:M1 {Lodging_Allowance: 'Actual', Boarding_Allowance: 'Actual', Personal_Incidental_Allowance: 'Actual'})", 'MERGE (a:M2 {Lodging_Allowance: 4000, Boarding_Allowance: 3000, Personal_Incidental_Allowance: 1000, other: 150})', 'MERGE (a:M3 {Lodging_Allowance: 3000, Boarding_Allowance: 2000, Personal_Incidental_Allowance: 800, other: 125})', 'MERGE (a:M4 {Lodging_Allowance: 2000, Boarding_Allowance: 1500, Personal_Incidental_Allowance: 600, other: 100})', 'MERGE (a:M5 {Lodging_Allowance: 1500, Boarding_Allowance: 1200, Personal_Incidental_Allowance: 500, other: 75})']
# .M6 has Lodging Allowance of 1000, Boarding Allowance of 700, Personal Incidental Allowance of 350, and 50.The maximum permissible rates mentioned in Table4 are exclusive of taxes .An employee staying at a relative's or friend's place during an official tour will receive 250 Rs. per day as lodging reimbursement.Employees can claim 7 .0 Rs per KM for using a Four Wheeler for official work.Employees can claim 2.5 Rs per KM for using a Two Wheeler for official work.The Day Tour Entitlement is calculated on a 24-hour clock basis .The start time of a tour is the start time of departure and the end time is the return time of the tour.For part days, the calculation of duration is as indicated in Table 6 .Table 6 specifies the following duration and entitlement: 3 to 12 hours is 50% of daily allowance, and 12 to 24 hours is 100% of daily allowance
# {'entities': [{'name': 'Lodging Allowance', 'type': 'Allowance', 'properties': {'amount': 1000}}, {'name': 'Boarding Allowance', 'type': 'Allowance', 'properties': {'amount': 700}}, {'name': 'Personal Incidental Allowance', 'type': 'Allowance', 'properties': {'amount': 350}}, {'name': 'Employee', 'type': 'Person', 'properties': {'lodgingReimbursement': 250}}, {'name': 'Four Wheeler', 'type': 'Vehicle', 'properties': {'claimRate': 7.0}}, {'name': 'Two Wheeler', 'type': 'Vehicle', 'properties': {'claimRate': 2.5}}, {'name': 'Day Tour Entitlement', 'type': 'Entitlement', 'properties': {'calculationBasis': '24-hour clock'}}, {'name': 'Table 4', 'type': 'Table', 'properties': {'description': 'Maximum permissible rates'}}, {'name': 'Table 6', 'type': 'Table', 'properties': {'description': 'Duration and entitlement'}}], 'relations': [{'source': 'Employee', 'target': 'Lodging Allowance', 'type': 'HAS_ALLOWANCE'}, {'source': 'Employee', 'target': 'Boarding Allowance', 'type': 'HAS_ALLOWANCE'}, {'source': 'Employee', 'target': 'Personal Incidental Allowance', 'type': 'HAS_ALLOWANCE'}, {'source': 'Employee', 'target': 'Four Wheeler', 'type': 'USES_VEHICLE_FOR_OFFICIAL_WORK', 'properties': {'claimRate': 7.0}}, {'source': 'Employee', 'target': 'Two Wheeler', 'type': 'USES_VEHICLE_FOR_OFFICIAL_WORK', 'properties': {'claimRate': 2.5}}, {'source': 'Day Tour Entitlement', 'target': 'Table 6', 'type': 'CALCULATED_USING_TABLE'}, {'source': 'Maximum Permissible Rates', 'target': 'Table 4', 'type': 'DEFINED_IN_TABLE'}]}
# WARNING:root:LLM response not in existing types: 'To determine if the NEW vertex TYPE 'vehicle' is equivalent to any of the EXISTING VERTEX TYPES, let's analyze the possibilities:
#
# 1. **Exact Match**: There isn't an exact match for 'vehicle' in the provided list.
# 2. **Variation, Abbreviation, Misspelling, or Synonym**:
#    - 'vehicle' can be considered a synonym for types like 'mode of travel', 'travel type', 'traveltype', 'category', or specific modes of transport like 'Four_Wheeler', 'Two_Wheeler', 'Bus', 'Train', 'Taxi_AC', 'Taxi_non_AC', 'Taxi_Auto_Public_Conveyance', 'Air', 'Auto_Taxi', 'Flight', 'Taxi'.
#
# Given these possibilities, the closest and most general synonym that 'vehicle' could relate to would be 'mode of travel' or 'travel type'/'traveltype', as 'vehicle' broadly categorizes various means of transportation, not limited to but including 'Four_Wheeler', 'Two_Wheeler', 'Bus', 'Taxi', etc.
#
# However, between 'mode of travel', 'travel type', and 'traveltype', these are essentially capturing the same concept:
#
# - **'mode of travel'** directly refers to the type or category of transportation used.
# - **'travel type'** and **'traveltype'** seem to refer to the categorization of travel, likely similar to 'mode of travel'.
#
# The closest and most appropriate match from the list provided would be **'mode of travel'**, as it directly refers to a category that includes 'vehicle' as a broad term.
#
# **mode of travel**'
# WARNING:root:LLM response not in existing types: 'entitlement'
# or
# 'Tour_Entitlements',
# or
# 'Deputation_Entitlements'
#
# The best match seems to be
# 'Tour_Entitlements'
# or
# 'Deputation_Entitlements'
#
# Since 'entitlement' seems more close to 'Tour_Entitlements' and 'Deputation_Entitlements', and
# 'Entitlement' is singular form of 'Entitlements'. I choose
#
# NONE'
# WARNING:root:LLM response not in existing types: 'Table8
# Table4'
# WARNING:root:LLM response not in existing types: 'To determine if the new edge type 'calculated_using_table' is equivalent to any of the existing edge types, let's analyze the meanings and see if there are any close matches.
#
# The new type 'calculated_using_table' suggests a relationship where something (possibly a value, a result, etc.) is derived or determined using a table.
#
# Looking at the existing types:
# - 'calculated_using_table' does not directly match any existing type but seems to relate to how something is determined or defined.
# - 'defined_in' could be considered close since it implies something is defined within a specific context (which could be a table).
#
# However, 'defined_in' does not exactly convey the active process of calculation or derivation that 'calculated_using_table' implies.
#
# Upon closer inspection:
# - There isn't a direct synonym or an exact match.
# - 'defined_in' might be the closest in terms of involving a source or basis for information, but it's not a perfect match.
#
# Given the specific nature of 'calculated_using_table' and comparing it to the existing types, it seems that it doesn't directly align with any but could conceptually relate to 'defined_in' in certain contexts. However, based on the instruction to return an exact match or 'NONE' if it's entirely new:
#
# The closest in terms of conceptual relation might seem to be 'defined_in', but given the nuances and the direct request:
#
# NONE'
# ❌ Failed to parse response: invalid syntax (<string>, line 1)
# Raw LLM Output: Here is the list of Cypher queries:
#
# ```python
# ["MERGE (a:Employee {lodgingReimbursement: 250}) MERGE (b:Lodging_Allowance {amount: 1000}) MERGE (a)-[:entitled_to]->(b)",
#  "MERGE (a:Employee {lodgingReimbursement: 250}) MERGE (b:Lodging_Allowance {amount: 700}) MERGE (a)-[:entitled_to]->(b)",
#  "MERGE (a:Employee {lodgingReimbursement: 250}) MERGE (b:Lodging_Allowance {amount: 350}) MERGE (a)-[:entitled_to]->(b)",
#  "MERGE (a:Employee {lodgingReimbursement: 250}) MERGE (b:vehicle {claimRate: 7.0}) MERGE (a)-[:travels_by {claimRate: 7.0}]->(b)",
#  "MERGE (a:Employee {lodgingReimbursement: 250}) MERGE (b:vehicle {claimRate: 2.5}) MERGE (a)-[:travels_by {claimRate: 2.5}]->(b)",
#  "MERGE (a:entitlement {calculationBasis: '24-hour clock'}) MERGE (b:table {description: 'Duration and entitlement'}) MERGE (a)-[:calculated_using_table]->(b)",
#  "MERGE (a:table {description: 'Maximum permissible rates'}) MERGE (b:table {description: 'Table4'}) MERGE (a)-[:defined_in]->(b)"]
# ```
#
# However I noticed there are some missing types in the relations section.
#
# Assuming  "Lodging Allowance",  "Boarding Allowance", "Personal Incidental Allowance" are of type "Lodging_Allowance" and
# "Maximum Permissible Rates" is of type "table".
#
# I have made necessary corrections.
#
# ```python
# ["MERGE (a:Employee {lodgingReimbursement: 250}) MERGE (b:Lodging_Allowance {amount: 1000}) MERGE (a)-[:entitled_to]->(b)",
#  "MERGE (a:Employee {lodgingReimbursement: 250}) MERGE (b:Lodging_Allowance {amount: 700}) MERGE (a)-[:entitled_to]->(b)",
#  "MERGE (a:Employee {lodgingReimbursement: 250}) MERGE (b:Lodging_Allowance {amount: 350}) MERGE (a)-[:entitled_to]->(b)",
#  "MERGE (a:Employee {lodgingReimbursement: 250}) MERGE (b:vehicle {claimRate: 7.0}) MERGE (a)-[:travels_by {claimRate: 7.0}]->(b)",
#  "MERGE (a:Employee {lodgingReimbursement: 250}) MERGE (b:vehicle {claimRate: 2.5}) MERGE (a)-[:travels_by {claimRate: 2.5}]->(b)",
#  "MERGE (a:entitlement {calculationBasis: '24-hour clock'}) MERGE (b:table {description: 'Duration and entitlement'}) MERGE (a)-[:calculated_using_table]->(b)",
#  "MERGE (a:table {description: 'Maximum Permissible Rates'}) MERGE (b:Table4 {description: 'Table4'}) MERGE (a)-[:defined_in]->(b)"]
# ```
# []
# .All expense claims, except for Boarding and Personal incidental category, must be supported by bills/invoices
# {'entities': [{'name': 'Expense Claim', 'type': 'Concept', 'properties': {'supportingDocuments': 'bills/invoices'}}, {'name': 'Boarding', 'type': 'Category', 'properties': {}}, {'name': 'Personal Incidental', 'type': 'Category', 'properties': {}}], 'relations': [{'source': 'Expense Claim', 'target': 'Boarding', 'type': 'EXCLUDES', 'properties': {}}, {'source': 'Expense Claim', 'target': 'Personal Incidental', 'type': 'EXCLUDES', 'properties': {}}, {'source': 'Expense Claim', 'target': 'bills/invoices', 'type': 'REQUIRES', 'properties': {}}]}
# WARNING:root:LLM response not in existing types: 'NONE'
# WARNING:root:LLM response not in existing types: 'The new edge type 'excludes' seems to be closely related to 'excluded_by' is not in the list, but 'includes' and 'excludes' are often considered antonyms. However, there's an existing type 'includes'.
#
# Given that 'excludes' is not exactly present but 'includes' is, and they are related concepts, the closest match in terms of semantic meaning would likely relate to its antonym or very close concept which is 'includes'.
#
# Therefore, based on the antonymous relationship and close semantic meaning:
#
# includes'
# ["MERGE (a:Expense_Claim {supportingDocuments: 'bills/invoices'}) MERGE (b:Boarding) MERGE (a)-[:excludes]->(b)", "MERGE (a:Expense_Claim {supportingDocuments: 'bills/invoices'}) MERGE (b:Personal_Incidental) MERGE (a)-[:excludes]->(b)", "MERGE (a:Expense_Claim {supportingDocuments: 'bills/invoices'}) MERGE (b:bills_invoices) MERGE (a)-[:requires]->(b)"]
# .A travel for a duration greater than 15 days but less than 1 year at one location or site is treated as deputation .During deputation, the employee is eligible to get entitlements as follows: for 1-7 days, benefits are as per the tour policy mentioned in Point A
# {'entities': [{'name': 'Deputation', 'type': 'Concept', 'properties': {'duration': 'greater than 15 days but less than 1 year'}}, {'name': 'Employee', 'type': 'Person', 'properties': {}}, {'name': 'Tour Policy', 'type': 'Policy', 'properties': {'benefits': 'as per Point A'}}], 'relations': [{'source': 'Deputation', 'target': 'Employee', 'type': 'AFFECTS', 'properties': {'benefits': 'eligible for entitlements'}}, {'source': 'Deputation', 'target': 'Tour Policy', 'type': 'RELATED_TO', 'properties': {'duration': '1-7 days'}}]}
# ["MERGE (a:Deputation {duration: 'greater than15 days but less than1 year'}) MERGE (b:Employee) MERGE (a)-[:affected_by {benefits: 'eligible for entitlements'}]->(b)", "MERGE (a:Deputation {duration: 'greater than15 days but less than1 year'}) MERGE (b:Tour_Policy {benefits: 'as per Point A'}) MERGE (a)-[:related_to {duration: '1-7 days'}]->(b)"]
# .After 7 days of deputation, allowances are provided as per Table 7: Deputation Entitlements, which specifies entitlements by grade .Table 7 includes the following entitlements: Lodging Allowance per month and Boarding Allowance per day.The category A travel allowance is 4500 per day.The category B travel allowance is 4000 per day .The daily allowance for category A is 250.The daily allowance for category B is 200.The accommodation allowance for category A is 150.The accommodation allowance for category B is 150 .The M4 travel allowance is 4000 per day.The M5 and M6 travel allowance is 4000 per day.The daily allowance for M4, M5, and M6 is 250.The accommodation allowance for M4, M5, and M6 is 150 .If a company provides guest house and food facilities at a site, an employee is not entitled to any travel allowances.An employee does not require to submit bills for deputation entitlements

# %% [raw]
# run_cypher("""MERGE (hod:HeadOfDepartment {name: 'Jane Smith'})
# MERGE (d:Department {name: 'IT Department'})
# MERGE (hod)-[:is_greatest]->(d)
# """)
